# %%
#%pip install pandas
# %pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests>=2.28.1 in /opt/anaconda3/envs/data_pip/lib/python3.13/site-packages (from sodapy) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/data_pip/lib/python3.13/site-packages (from requests>=2.28.1->sodapy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/data_pip/lib/python3.13/site-packages (from requests>=2.28.1->sodapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/data_pip/lib/python3.13/site-packages (from requests>=2.28.1->sodapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/data_pip/lib/python3.13/site-packages (from requests>=2.28.1->sodapy) (2024.8.30)
# Downloading sodapy-2.2.0-py2.py3-none-any.whl (15 kB)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("www.datos.gov.co", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(www.datos.gov.co,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("n6vw-vkfe", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#      fecha_instalacion  estado    codigo                          nombre  \
# 0           2016-11-15  Activa  52057100      RUMICHACA - AUT [52057100]
# 1           2005-12-10  Activa  52055170    LA JOSEFINA - AUT [52055170]
# 2           2004-03-01  Activa  52055220     EL PARAISO - AUT [52055220]
# 3           2005-11-11  Activa  44015070      EL PEPINO - AUT [44015070]
# 4           2005-07-19  Activa  48015040  PUERTO NARINO - AUT [48015040]
# ...                ...     ...       ...                             ...
# 1995        1986-12-15  Activa  21210200         BUENOS AIRES [21210200]
# 1996        1999-02-15  Activa  26127030             BARRAGAN [26127030]
# 1997        1977-03-15  Activa  35127020           CAMP YUCAO [35127020]
# 1998        1985-03-15  Activa  21217140         PUENTE LUISA [21217140]
# 1999        1986-11-15  Activa  21215130     CUCUANA HACIENDA [21215130]
#
#      departamento            categoria altitud  \
# 0          Nariño         Limnigráfica    2582
# 1          Nariño  Climática Principal    2450
# 2          Nariño  Climática Principal    3120
# 3        Putumayo  Climática Principal     760
# 4        Amazonas  Climática Principal     158
# ...           ...                  ...     ...
# 1995       Tolima        Pluviométrica     728
# 1996      Quindío         Limnimétrica     113
# 1997         Meta         Limnigráfica     147
# 1998       Tolima         Limnimétrica    2205
# 1999       Tolima  Climática Ordinaria    2229
#
#                                               ubicaci_n corriente  \
# 0     {'latitude': '0.81378611', 'needs_recoding': F...  Guaitara
# 1     {'latitude': '0.93030556', 'needs_recoding': F...  Guaitara
# 2     {'latitude': '1.07061111', 'needs_recoding': F...  Guaitara
# 3     {'latitude': '1.08288889', 'needs_recoding': F...  Guaitara
# 4     {'latitude': '-3.78030556', 'needs_recoding': ...  Amazonas
# ...                                                 ...       ...
# 1995  {'latitude': '4.33513889', 'needs_recoding': F...     Lejos
# 1996  {'latitude': '4.33744444', 'needs_recoding': F...  Barragan
# 1997  {'latitude': '4.34055556', 'needs_recoding': F...     Yucao
# 1998  {'latitude': '4.34136111', 'needs_recoding': F...    Anaime
# 1999  {'latitude': '4.34138889', 'needs_recoding': F...    Anaime
#
#           municipio fecha_suspension
# 0           Ipiales              NaN
# 1         Contadero              NaN
# 2         Túquerres              NaN
# 3             Mocoa              NaN
# 4     Puerto Nariño              NaN
# ...             ...              ...
# 1995         Ibagué              NaN
# 1996          Pijao              NaN
# 1997   Puerto López              NaN
# 1998      Cajamarca              NaN
# 1999      Cajamarca              NaN
#
# [2000 rows x 11 columns]
